# %%
import pandas as pd
import numpy as np

df = pd.read_csv("raw_data/swiggy_vs_zomato_enriched.csv")
df.head()
# Out:
#   restaurant_id     restaurant_name       city     locality  latitude  \
# 0    REST000001       Tandoor House    Chennai    Velachery  13.11092
# 1    REST000002         Copper Deck      Delhi  Mayur Vihar  28.80022
# 2    REST000003      The Fast House  Ahmedabad    Satellite  22.99754
# 3    REST000004          Urban Bowl    Chennai     Perambur  13.04000
# 4    REST000005  Golden Kitchen Co.     Mumbai  Lower Parel  19.13642
#
#    longitude      restaurant_type                cuisines  \
# 0   80.16023        Cloud Kitchen  Fast Food; Continental
# 1   77.12131  QSR (Quick Service)                    Thai
# 2   72.49951        Casual Dining               Fast Food
# 3   80.27945                 Cafe            Korean; Cafe
# 4   72.94463           Food Truck                 Seafood
#
#         top_selling_dish  distance_from_city_center_km  ... amenities_count  \
# 0                  Fries                           0.5  ...               6
# ...

# %%
df.shape
df.isnull().sum()
# Out:
# restaurant_id                           0
# restaurant_name                         0
# city                                    0
# locality                                0
# latitude                                0
# longitude                               0
# restaurant_type                         0
# cuisines                                0
# top_selling_dish                        0
# distance_from_city_center_km            0
# opening_time                            0
# closing_time                            0
# operating_days_per_week                 0
# seating_capacity                        0
# swiggy_rating                           0
# swiggy_total_reviews                    0
# zomato_rating                           0
# zomato_total_reviews                    0
# average_rating_both_platforms           0
# customer_sentiment_score                0
# avg_cost_per_person_inr                 0
# price_category                          0
# ...

# %% [markdown]
# Observation: NO duplicate records found.

# %%
df.describe().T
# Out:
#                                        count           mean           std  \
# latitude                              8000.0      19.944546      5.449833
# longitude                             8000.0      77.031232      4.013453
# distance_from_city_center_km          8000.0       6.068800      4.035941
# operating_days_per_week               8000.0       6.655500      0.567768
# seating_capacity                      8000.0      46.227000     39.675011
# swiggy_rating                         8000.0       4.371725      0.380041
# swiggy_total_reviews                  8000.0    1491.641625    782.091824
# zomato_rating                         8000.0       4.373325      0.378403
# zomato_total_reviews                  8000.0    1491.142750    771.773246
# average_rating_both_platforms         8000.0       4.372525      0.363931
# customer_sentiment_score              8000.0      87.356000      8.091026
# avg_cost_per_person_inr               8000.0     549.114875    409.553713
# ...

# %% [markdown]
# Observation: Numerical columns appear valid with no obvious anomalies

# %%
df["listing_date"] = pd.to_datetime(df["listing_date"])
df["listing_date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.to_csv(
    "processed_data/cleaned_swiggy_vs_zomato.csv",
    index=False
)
